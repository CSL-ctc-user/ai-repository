# %% [markdown]
# # Bedrock Helpdesk Agent Validation Notebook
#
# This notebook documents a simple AI/ML validation workflow for a helpdesk AI agent.
#
# Target repository: csl-ctc/ai-repository
#
# Target agent source: simple_agent/helpdesk_agent_bedrock.py
#
# Model provider: Amazon Bedrock
#
# Model reference: bedrock/amazon.nova-pro-v1:0

# %% [markdown]
# ## Validation purpose
#
# This notebook is intended to validate that the repository contains AI/ML assets including model usage, agent source code, and pipeline configuration.

# %%
MODEL_PROVIDER = "Amazon Bedrock"
MODEL_ID = "amazon.nova-pro-v1:0"
MODEL_REFERENCE = "bedrock/amazon.nova-pro-v1:0"
AGENT_FRAMEWORK = "OpenAI Agents SDK"
CONNECTOR_LIBRARY = "LiteLLM"

ai_asset = {
    "asset_type": "ai-agent",
    "framework": AGENT_FRAMEWORK,
    "model_provider": MODEL_PROVIDER,
    "model_id": MODEL_ID,
    "model_reference": MODEL_REFERENCE,
    "source_path": "simple_agent/helpdesk_agent_bedrock.py",
}

ai_asset

# %%
validation_questions = [
    "NomaでGitHubリポジトリが検出されない場合はどうすればいい？",
    "VPNに接続できない場合はどうすればいい？",
    "Bedrockのログを確認するにはどうすればいい？",
]

validation_questions

# %% [markdown]
# ## Expected AI/ML signals
#
# - OpenAI Agents SDK
# - Agent
# - Runner
# - LiteLLM
# - LitellmModel
# - Amazon Bedrock
# - bedrock/amazon.nova-pro-v1:0
# - model usage
# - AI helpdesk agent
